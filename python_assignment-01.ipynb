# %% [markdown]
# Python Assignment #01

# %% [markdown]
# 1:Variable:A vairable is a container in the memory that stores values temporarily.
# Syntax of variable:
# variable_name=value

# %%
#Example of a variable in python
variable_name="This is a variable"

# %% [markdown]
# 2:Rules for naming a variable in python:
# i:A variable name should contain alphabets(uppercase and lowercase), numbers and underscore only.
# ii:Variable name should start only with either an underscore or alphabet(upper or lower case).
# iii:Reserved words are not allowed to be used as variable name,like "for" is a reserved word and cannot be used as variable name.

# %%
# examples of incorrect variable names
for=20
1st_num="ayesha"
R@fhy=19
#examples of correct variables names
For=20
first_num="ayesha"

# %% [markdown]
# 3:Integer Datatype:Integer datatype contains whole numbers only.

# %%
# example of an integer datatype variable
weight=30
type(weight)
# Out:
# int

# %% [markdown]
# 4:Float Datatype:Float datatype contains numbers with decimal points.

# %%
# example of a float datatype variable
height=22.8
type(height)
# Out:
# float

# %% [markdown]
# 5:String Datatype:String datatype is a sequence of characters that stores text.
# There are two types of strings:
# i:Single line string:Single line string is single line and written within double quotes.
# ii:Multiline String:Multiline string is multiline and written within triple double quotes.

# %%
#example of a single line string
name="My name is Abdul Rafhy"
#example of a multiline string
description="""I am an Ai student,
studying at University
of Azad Jammu and Kashmir."""
type(description)

print(name)
print(type(name))
print(description)
print(type(description))
# Out:
# <class 'str'>
# My name is Abdul Rafhy
# I am an Ai student,
# studying at University
# of Azad Jammu and Kashmir.
