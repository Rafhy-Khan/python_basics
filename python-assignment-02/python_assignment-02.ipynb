# %% [markdown]
# # Python Assignment#02

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# **1:Write a python program to add two numbers and print the result.**

# %%
num1,num2=34,68 #taking two numbers
sum=num1 + num2  #adding two numbers
print(sum)  #displaying the result
# Out:
# 102

# %% [markdown]
# **2:Write a python program to find the remainder when one number is divided by another**

# %%
numb1,numb2=20,9 #taking two numbers
remainder=numb1 % numb2 #dividing two numbers
print(remainder) #displaying the result
# Out:
# 2

# %% [markdown]
# **3:Write a python program to calculate the square of a number using the power operator**

# %%
number=3 
exponent=2
square=3**2 #calculating square
print(square) #displaying the result
# Out:
# 9

# %% [markdown]
# ## Assignment Operators

# %% [markdown]
# **1:Write a python program that assigns a value then increases it by 5 using an assignment operator**

# %%
assign=25 #assigning value
assign+=5 #increasing the value by 5
print(assign) #displaying the result
# Out:
# 30

# %% [markdown]
# **2:Write a python program that multiplies a variable by 2 using an assignment operator**

# %%
variable=10 #taking a variable
variable*=2 #multiplying it by 2
print(variable) #displaying the result
# Out:
# 20

# %% [markdown]
# **3:Write a python program that subtracts 10 from a variable using an assignment operator**

# %%
variable1=40 #taking a variable
variable1-=10 #subtracting 2 from it
print(variable1) #displaying the result
# Out:
# 30

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# **1:Write a python program to check whether two numbers are equal or not**

# %%
number1,number2=25,35 #taking two numbers
result=number1==number2 #checking if they are equal or not
print(result) #True means Equal and False means Not Equal
# Out:
# False

# %% [markdown]
# **2:Write a program to check if one number is greater than another**

# %%
num1,num2=45,78
if(num1>num2): #if num1 is greater than num2
    print("num1 is greater than num2")
else:
    print("num2 is greater than num1")
# Out:
# num2 is greater than num1

# %% [markdown]
# **3:Write a python program to compare two numbers and print whether the first number is less thann or equal to the second number**

# %%
firstNum,secondNum=99,99
if(firstNum<secondNum): #if firstNum is less than secondNum
    print("Fisrt number is less than Second Number")

elif(firstNum==secondNum): #if firstNum is equal to the secondNum
    print("First number is equal to Second Number")

else:
    print("First number is greater than Second Number")
# Out:
# First number is equal to Second Number

# %% [markdown]
# ## Logical Operators

# %% [markdown]
# **1:Write a python program that checks if a number is greater than 5 and less than 20**

# %%
number=17
if(number>5):
    if(number<20):
        print("Number is greater than 5 and less than 20")
    else:
        print("Number is greater than 5 but not less than 20")
else:
    print("Number is not even greater than 5")
# Out:
# Number is greater than 5 and less than 20

# %% [markdown]
# **2:Write a python program that checks if a number is less than 10 or greater than 50**

# %%
num=34
if(num<10):
    print("num is less than 10")
elif(num>50):
    print("num is greater than 50")
else:
    print("num is neither less than 10 nor greater than 50")
# Out:
# num is neither less than 10 nor greater than 50

# %% [markdown]
# **3:Write a python program that uses not operator to reverse the condition**

# %%
a=True
b=False
print(f"a={not a}") #a=True becomes a=False
print(f"b={not b}") #b=False becomes b=True
# Out:
# a=False
# b=True

# %% [markdown]
# ## Memebership Operators

# %% [markdown]
# **1:Write a python program to check if a number exists in a given list**

# %%
List=[34,45,32,65,21] #creating a list
if(45 in List): #checking 45 is present in List
    print("45 exists in List")
else:
    print("45 doesn't exist in List")
# Out:
# 45 exist in List

# %% [markdown]
# **2:Write a python program to check if a word exists in a given string**

# %%
string="My name is Abdul Rafhy"
if("Abdul Rafhy" in string): #checking Abdul Rafhy is present in string
    print("Abdul Rafhy exists in the string")
else:
    print("Abdul Rafhy doesn't exist in the string")
# Out:
# Abdul Rafhy exists in the string

# %% [markdown]
# **3:Write a python program to check whether a value is not present in a tuple**

# %%
Tuple=(45,65,32,12,89) #creating a tuple
if(88 not in Tuple): #checking 88 not present in Tuple
    print("88 doesn't exist in Tuple")
else:
    print("88 exists in Tuple")
# Out:
# 88 doesn't exist in Tuple

# %% [markdown]
# # Thankyou!
